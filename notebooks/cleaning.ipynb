# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/Access_to_Tech_Dataset.csv")

# %% [markdown]
# Fix id Column Type

# %%
df[df['violation_category'].isna()] # Fix Missing Violation Categories
# Out:
#           id  web_URL_id            domain_category  \
# 3507  6007.0  3101899065  TechnologyScienceResearch
# 3516  6016.0    37517988  TechnologyScienceResearch
# 3518  6018.0   111849147  TechnologyScienceResearch
# 3519  6019.0  4643564980  TechnologyScienceResearch
#
#                                                 web_URL scrape_status  \
# 3507           https://act-rules.github.io/rules/5c01ea       scraped
# 3516  https://dequeuniversity.com/rules/axe/4.10/for...       scraped
# 3518  https://dequeuniversity.com/rules/axe/4.10/ari...       scraped
# 3519  https://dequeuniversity.com/rules/axe/4.10/ari...       scraped
#
#       html_file_name                                     html_file_path  \
# 3507  3101899065.txt  /Volumes/MacPema/HIWI/WebAccessibility-main/20...
# 3516    37517988.txt  /Volumes/MacPema/HIWI/WebAccessibility-main/20...
# 3518   111849147.txt  /Volumes/MacPema/HIWI/WebAccessibility-main/20...
# ...

# %%
df['violation_category'] = df['violation_category'].fillna('Unknown') # Fill missing categories as "Unknown":
# Out:
# np.int64(3467)

# %%
df['domain_category'] = df['domain_category'].replace({
    'TechnologyScienceResearch': 'Technology / Science / Research'
})

# %%
df['high_severity'] = df['violation_score'] >= 4 # Severity Flag

# %%
df.to_csv("../data/clean_access.csv", index=False)

# %%
df.info()
df.head()  
df['high_severity'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3524 entries, 0 to 3523
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         57 non-null     float64
#  1   web_URL_id                 3524 non-null   int64
#  2   domain_category            3524 non-null   object
#  3   web_URL                    3524 non-null   object
#  4   scrape_status              3524 non-null   object
#  5   html_file_name             3524 non-null   object
#  6   html_file_path             3524 non-null   object
#  7   violation_count            3524 non-null   int64
#  8   violation_name             3524 non-null   object
#  9   violation_score            3524 non-null   int64
#  10  violation_description      3524 non-null   object
#  11  violation_description_url  3523 non-null   object
#  12  affected_html_elements     3472 non-null   object
# ...
