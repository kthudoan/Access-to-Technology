# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/Access_to_Tech_Dataset.csv")

# %%
df.head()
df.shape
# Out:
# (3524, 17)

# %%
df.tail()
# Out:
#         id  web_URL_id            domain_category  \
# 3519  6019  4643564980  TechnologyScienceResearch
# 3520  6020   581517740  TechnologyScienceResearch
# 3521  6021  2182179087  TechnologyScienceResearch
# 3522  6022   853326546  TechnologyScienceResearch
# 3523  6023  4925950366                  Ecommerce
#
#                                                 web_URL scrape_status  \
# 3519  https://dequeuniversity.com/rules/axe/4.10/ari...       scraped
# 3520  https://dequeuniversity.com/rules/axe/4.10/tar...       scraped
# 3521  https://dequeuniversity.com/rules/axe/4.10/emp...       scraped
# 3522  https://dequeuniversity.com/rules/axe/4.10/ari...       scraped
# 3523                        https://www.aliexpress.com/       scraped
#
#       html_file_name                                     html_file_path  \
# 3519  4643564980.txt  /Volumes/MacPema/HIWI/WebAccessibility-main/20...
# 3520   581517740.txt  /Volumes/MacPema/HIWI/WebAccessibility-main/20...
# ...

# %%
df.columns
# Out:
# Index(['id', 'web_URL_id', 'domain_category', 'web_URL', 'scrape_status',
#        'html_file_name', 'html_file_path', 'violation_count', 'violation_name',
#        'violation_score', 'violation_description', 'violation_description_url',
#        'affected_html_elements', 'violation_category', 'violation_impact',
#        'wcag_reference', 'supplementary_information'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3524 entries, 0 to 3523
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         3524 non-null   object
#  1   web_URL_id                 3524 non-null   int64
#  2   domain_category            3524 non-null   object
#  3   web_URL                    3524 non-null   object
#  4   scrape_status              3524 non-null   object
#  5   html_file_name             3524 non-null   object
#  6   html_file_path             3524 non-null   object
#  7   violation_count            3524 non-null   int64
#  8   violation_name             3524 non-null   object
#  9   violation_score            3524 non-null   int64
#  10  violation_description      3524 non-null   object
#  11  violation_description_url  3523 non-null   object
#  12  affected_html_elements     3472 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# id                              0
# web_URL_id                      0
# domain_category                 0
# web_URL                         0
# scrape_status                   0
# html_file_name                  0
# html_file_path                  0
# violation_count                 0
# violation_name                  0
# violation_score                 0
# violation_description           0
# violation_description_url       1
# affected_html_elements         52
# violation_category              4
# violation_impact                0
# wcag_reference                  0
# supplementary_information    1678
# dtype: int64

# %%
df['scrape_status'].value_counts()
# Out:
# scrape_status
# scraped    3524
# Name: count, dtype: int64

# %%
df['domain_category'].value_counts()
# Out:
# domain_category
# News and Media                     940
# Technology Science and Research    633
# Educational Platforms              575
# Streaming Platforms                463
# Government and Public Services     380
# E-commerce                         344
# Health and Wellness                165
# TechnologyScienceResearch           23
# Ecommerce                            1
# Name: count, dtype: int64

# %%
df.to_csv("../data/backup_access.csv", index=False)
